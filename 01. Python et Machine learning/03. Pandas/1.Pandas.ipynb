# %% [markdown]
# # La bibliothèque Pandas

# %% [markdown]
# on peut créer un dataframe à partir d'une array numpy (mais ce n'est pas très pratique et le type des données est le même pour toutes les colonnes, ici float64) :

# %%
import pandas as pd
import numpy as np

ar = np.array([[1.1, 2, 3.3, 4], [2.7, 10, 5.4, 7], [5.3, 9, 1.5, 15]])
df = pd.DataFrame(ar, index = ['a1', 'a2', 'a3'], columns = ['A', 'B', 'C', 'D'])
df
# Out:
#       A     B    C     D
# a1  1.1   2.0  3.3   4.0
# a2  2.7  10.0  5.4   7.0
# a3  5.3   9.0  1.5  15.0

# %% [markdown]
# on peut aussi créer le dataframe avec un dictionnaire :

# %%
dic = {'A': [1.1, 2.7, 5.3], 'B': [2, 10, 9], 'C': [3.3, 5.4, 1.5], 'D': ['a', 'b', 'c']}
    
df = pd.DataFrame(dic, index = ['a1', 'a2', 'a3'])

df
# Out:
#       A   B    C  D
# a1  1.1   2  3.3  a
# a2  2.7  10  5.4  b
# a3  5.3   9  1.5  c

# %% [markdown]
# ## Lire un fichier CSV avec pandas

# %% [markdown]
# - Importer la librairie pandas.
# - Utiliser la fonction pandas.read_csv() pour lire le fichier "food_info.csv" (téléchargeable dans les ressources de cette vidéo) dans un dataframe qu'on nomme food_info.
# - Utiliser les fonctions type() et print() pour afficher le type de food_info et confirmer qu'il s'agit d'un objet dataframe.

# %%
import pandas as pd

food_info = pd.read_csv("Jeux_de_donnees/food_info.csv")
print(type(food_info))
print()
print(food_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %% [markdown]
# ## Sélectionner une ligne

# %% [markdown]
# - Assigner la 100e ligne du dataframe food_info à la variable row_100.
# - Afficher le résultat.

# %%
row_100 = food_info.loc[99]
print(type(row_100))
print()
row_100
# Out:
# <class 'pandas.core.series.Series'>
# NDB_No                                  1111
# Shrt_Desc          MILK SHAKES THICK VANILLA
# Water_(g)                              74.45
# Energ_Kcal                               112
# Protein_(g)                             3.86
# Lipid_Tot_(g)                           3.03
# Ash_(g)                                 0.91
# Carbohydrt_(g)                         17.75
# Fiber_TD_(g)                               0
# Sugar_Tot_(g)                          17.75
# Calcium_(mg)                             146
# Iron_(mg)                                0.1
# Magnesium_(mg)                            12
# Phosphorus_(mg)                          115
# Potassium_(mg)                           183
# Sodium_(mg)                               95
# Zinc_(mg)                               0.39
# Copper_(mg)                            0.051
# Manganese_(mg)                         0.014
# Selenium_(mcg)                           2.3
# ...

# %% [markdown]
# ## Sélectionner plusieurs lignes

# %%
num_rows = food_info.shape[0]
print(num_rows)
print(num_rows-5)
print(num_rows-1)
# Out:
# 8618
# 8613
# 8617

# %%
last_rows = food_info.loc[num_rows - 5 : num_rows-1]
last_rows
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %% [markdown]
# - Sélectionner les 5 dernières lignes de food_info et assigner le résultat à la variable last_rows.

# %% [markdown]
# ## Sélectionner une colonne plutôt qu'une ligne

# %% [markdown]
# - Assigner la colonne "protein_(g)" à la variable protein.
# - Assigner la colonne "Cholestrl_(mg)" à la variable cholesterol.
# - Afficher les résultats.

# %%
protein = food_info["Protein_(g)"]
cholesterol = food_info["Cholestrl_(mg)"]

# %%
print(type(protein))
print()
print(protein)
# Out:
# <class 'pandas.core.series.Series'>
#
# 0        0.85
# 1        0.85
# 2        0.28
# 3       21.40
# 4       23.24
#         ...
# 8613    18.50
# 8614    20.54
# 8615     0.00
# 8616    16.10
# 8617    19.80
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
print(cholesterol)
# Out:
# 0       215.0
# 1       219.0
# 2       256.0
# 3        75.0
# 4        94.0
# 5       100.0
# 6        72.0
# 7        93.0
# 8       102.0
# 9       103.0
# 10       95.0
# 11       17.0
# 12       13.0
# 13        7.0
# 14       12.0
# 15        4.0
# 16      110.0
# 17       89.0
# 18       89.0
# 19      116.0
# 20       94.0
# 21      114.0
# 22      110.0
# 23       90.0
# 24       89.0
# 25       79.0
# 26       89.0
# 27       64.0
# 28       65.0
# 29       96.0
#         ...
# 8588      0.0
# 8589      0.0
# 8590      0.0
# 8591      0.0
# 8592      0.0
# 8593      0.0
# 8594      0.0
# 8595     35.0
# 8596      0.0
# 8597     54.0
# 8598      0.0
# 8599      0.0
# 8600      0.0
# 8601      6.0
# 8602      0.0
# 8603      0.0
# 8604      0.0
# 8605      0.0
# 8606      0.0
# 8607      0.0
# 8608      0.0
# 8609      0.0
# 8610      0.0
# 8611      0.0
# 8612     50.0
# 8613     95.0
# 8614     41.0
# 8615      0.0
# 8616     50.0
# 8617     50.0
# ...

# %% [markdown]
# ## Sélectionner plusieurs colonnes

# %% [markdown]
# - Sélectionner les colonnes 'Shrt__Desc', 'Selenium_(mcg)' et 'Thiamin_(mg)' et assigner le dataframe résultant à la variable selenium_thiamin.
# - Afficher le résultat.

# %%
selenium_thiamin = food_info[['Shrt_Desc', 'Selenium_(mcg)', 'Thiamin_(mg)']]
print(type(selenium_thiamin))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
selenium_thiamin
# Out:
#                        Shrt_Desc  Selenium_(mcg)  Thiamin_(mg)
# 0               BUTTER WITH SALT             1.0         0.005
# 1       BUTTER WHIPPED WITH SALT             1.0         0.005
# 2           BUTTER OIL ANHYDROUS             0.0         0.001
# 3                    CHEESE BLUE            14.5         0.029
# 4                   CHEESE BRICK            14.5         0.014
# ...                          ...             ...           ...
# 8613             MACKEREL SALTED            73.4         0.020
# 8614  SCALLOP (BAY&SEA) CKD STMD            21.7         0.012
# 8615                  SYRUP CANE             0.7         0.130
# 8616                   SNAIL RAW            27.4         0.010
# 8617            TURTLE GREEN RAW            16.8         0.120
#
# [8618 rows x 3 columns]

# %% [markdown]
# ## Cas pratique

# %% [markdown]
# - Sélectionner et afficher seulement les colonnes qui utilisent comme unité de mesure les grammes (c'est à dire qui se terminent par "(g)"). Pour cela:
# >- Utiliser l'attribut columns pour retourner le nom des colonnes du dataframe food_info et convertir en liste utilisant la méthode tolist()
# >- Créer une nouvelle liste qu'on nommera gram__columns, contenant seulement les colonnes se terminant par "(g)". Indice: la méthode endswith() retourne True si l'objet sur lequel on l'applique se termine par l'élément entre parenthèses. ex: total_(g).endswith("(g)") retourne True. Une boucle for est fortement conseillé pour parcourir tous les noms de colonne.
# >- Sélectionner les colonnes de gram_columns pour le dataframe food_info et assigner le dataframe résultat à la variable gram_df
# >- Afficher les 3 premières valeurs de ce dataframe gram_df

# %%
print(type(food_info.columns.tolist()))

print(food_info.columns.tolist())
# Out:
# <class 'list'>
# ['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)', 'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)', 'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)', 'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)', 'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)', 'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)']

# %%
col_names = food_info.columns.tolist()
gram_columns = []

for c in col_names:
    if c.endswith("(g)"):
        gram_columns.append(c)
        
gram_df = food_info[gram_columns]

gram_df.head(3)
# Out:
#    Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0      15.87         0.85          81.11     2.11            0.06
# 1      15.87         0.85          81.11     2.11            0.06
# 2       0.24         0.28          99.48     0.00            0.00
#
#    Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# 0           0.0           0.06      51.368       21.021        3.043
# 1           0.0           0.06      50.489       23.426        3.012
# 2           0.0           0.00      61.924       28.732        3.694
